# %%
# Import libraries
import pandas as pd
import numpy as np
import re
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Create driver
driver = webdriver.Chrome()

# Go to the character page
url = 'http://magical-menagerie.com/wizardry/full-character-listing/'
driver.get(url)

# Get elements
elements = driver.find_element(By.CLASS_NAME, 'postcontent')
sub_elem = elements.find_elements(By.TAG_NAME, 'p')

# img_elem = [sub_el.find_elements(By.TAG_NAME, 'img') for sub_el in sub_elem]
# alt_txt = []
# for elem in img_elem:
#     aux = []
#     for imgg in elem:
#         el = imgg.get_attribute('alt')
#         if el == "huffle": el = "hufflepuff" 
#         if el == "slyth": el = "slytherin" 
#         if el == "slug": el = "slug club" 
#         if el == "raven": el = "ravenclaw" 
#         if el == "quidd": el = "quidditch" 
#         if el == "gryff": el=  "gryffindor"        
#         aux.append(el)
#     alt_txt.append(aux)
# # alt_txt = [imgg.get_attribute('alt') for elem in img_elem for imgg in elem]

# print(alt_txt)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/service.py:72, in Service.start(self)
#      71     cmd.extend(self.command_line_args())
# ---> 72     self.process = subprocess.Popen(cmd, env=self.env,
#      73                                     close_fds=platform.system() != 'Windows',
#      74                                     stdout=self.log_file,
#      75                                     stderr=self.log_file,
#      76                                     stdin=PIPE)
#      77 except TypeError:
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1950, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1949         err_msg = os.strerror(errno_num)
# -> 1950     raise child_exception_type(errno_num, err_msg, err_filename)
#    1951 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chromedriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Create driver
# ----> 2 driver = webdriver.Chrome()
#       4 # Go to the character page
#       5 url = 'http://magical-menagerie.com/wizardry/full-character-listing/'
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:73, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      66         desired_capabilities.update(options.to_capabilities())
#      68 self.service = Service(
#      69     executable_path,
#      70     port=port,
#      71     service_args=service_args,
#      72     log_path=service_log_path)
# ---> 73 self.service.start()
#      75 try:
#      76     RemoteWebDriver.__init__(
#      77         self,
#      78         command_executor=ChromeRemoteConnection(
#      79             remote_server_addr=self.service.service_url,
#      80             keep_alive=keep_alive),
#      81         desired_capabilities=desired_capabilities)
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/service.py:81, in Service.start(self)
#      79 except OSError as err:
#      80     if err.errno == errno.ENOENT:
# ---> 81         raise WebDriverException(
#      82             "'%s' executable needs to be in PATH. %s" % (
#      83                 os.path.basename(self.path), self.start_error_message)
#      84         )
#      85     elif err.errno == errno.EACCES:
#      86         raise WebDriverException(
#      87             "'%s' executable may have wrong permissions. %s" % (
#      88                 os.path.basename(self.path), self.start_error_message)
#      89         )
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %%
len(alt_txt)
# Out:
# 959

# %%
# Extract tags which holds names
tags = [(element.find_elements(By.TAG_NAME, 'strong'), element.find_elements(By.TAG_NAME, 'img')) for element in sub_elem]

print(tags)

# # Eleminate empty results
# tags_upd = [elem for elem in tags if elem != []]

# # Extracte names
# names = [{'names':t.text} for tag in tags_upd[1:-1] for t in tag if t.text != '']
# Out:
# [([], []), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_976")>], [<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_977")>, <selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_978")>]), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_979")>], [<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_980")>]), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_981")>], [<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_982")>]), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_983")>], [<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_984")>]), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_985")>], []), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_986")>], [<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_987")>]), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_988")>, <selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_989")>], [<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_990")>]), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_991")>, <selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_992")>], []), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_993")>, <selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_994")>], []), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_995")>, <selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_996")>], []), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_997")>, <selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_998")>], []), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_999")>, <selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element="FD605DACDD20997E031E412B3219691A_element_1000")>], []), ([<selenium.webdriver.remote.webelement.WebElement (session="44f9b7e9ae96d4d255c1600b7a8772dc", element= ...

# %%
# DataFrame for names
character_names = pd.DataFrame(names)
# Delete paranthesis and what is inside them
character_names['names'] = character_names['names'].apply(lambda x: re.sub('[\(].*?[\)]','', x))

# Make new column for last names
character_names['last_name'] = character_names['names'].apply(lambda x: x.split(', ', 1)[0])
# Extracte first names
first_names= []
for name in character_names['names']:
    try:
        first_names.append(name.split(', ',1)[1])
    except:
        first_names.append('')
        
# Create new column for first names       
character_names['first_name'] = first_names

# %%
character_names
# Out:
#                    names    last_name  first_name
# 0     Abercrombie, Euan-  Abercrombie       Euan-
# 1     Ackerley, Steward-     Ackerley    Steward-
# 2       Aesalon, Falcon-      Aesalon     Falcon-
# 3                 Agnes-       Agnes-
# 4    Agrippa, Cornelius-      Agrippa  Cornelius-
# ..                   ...          ...         ...
# 695      Zabini, Blaise-       Zabini     Blaise-
# 696           Zabini, ?-       Zabini          ?-
# 697  Zamojski, Ladislaw-     Zamojski   Ladislaw-
# 698        Zeller, Rose-       Zeller       Rose-
# 699           Zograf, ?-       Zograf          ?-
#
# [700 rows x 3 columns]

# %%
# Cleane first_name column
character_names.first_name = character_names.first_name.str.replace('-','')
character_names.first_name = character_names.first_name.str.replace('–','')
character_names.first_name = character_names.first_name.str.replace('?','', regex=True)
character_names.first_name = character_names.first_name.str.strip(' ')

# Cleane last_name column
character_names.last_name = character_names.last_name.str.replace('-','')
character_names.last_name = character_names.last_name.str.replace('–','')
character_names.last_name = character_names.last_name.str.replace('?','', regex=True)
character_names.last_name = character_names.last_name.str.strip(' ')
# Update names column
character_names['names'] = character_names.first_name + ' ' + character_names.last_name

# %%
character_names
# Out:
#                  names    last_name first_name
# 0     Euan Abercrombie  Abercrombie       Euan
# 1     Steward Ackerley     Ackerley    Steward
# 2       Falcon Aesalon      Aesalon     Falcon
# 3                Agnes        Agnes
# 4    Cornelius Agrippa      Agrippa  Cornelius
# ..                 ...          ...        ...
# 695      Blaise Zabini       Zabini     Blaise
# 696             Zabini       Zabini
# 697  Ladislaw Zamojski     Zamojski   Ladislaw
# 698        Rose Zeller       Zeller       Rose
# 699             Zograf       Zograf
#
# [700 rows x 3 columns]

# %%
# Export data frame
# character_names.to_csv('character_names.csv')

# %%
df = character_names.drop_duplicates()

# %%
df
# Out:
#                  names    last_name first_name
# 0     Euan Abercrombie  Abercrombie       Euan
# 1     Steward Ackerley     Ackerley    Steward
# 2       Falcon Aesalon      Aesalon     Falcon
# 3                Agnes        Agnes
# 4    Cornelius Agrippa      Agrippa  Cornelius
# ..                 ...          ...        ...
# 695      Blaise Zabini       Zabini     Blaise
# 696             Zabini       Zabini
# 697  Ladislaw Zamojski     Zamojski   Ladislaw
# 698        Rose Zeller       Zeller       Rose
# 699             Zograf       Zograf
#
# [695 rows x 3 columns]

# %%
df.to_csv('no_duble.csv')
